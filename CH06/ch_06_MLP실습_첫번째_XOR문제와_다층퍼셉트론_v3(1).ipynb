# %% [markdown]
# # ch_06_MLP실습_첫번째_XOR 문제와 다층 퍼셉트론

# %%
# !git clone https://github.com/ballade8/Multi_Layer_Perceptron
#Git Hub 저장소에서 실습 관련 자료를 복제(Clone) 해온다.
# Out:
# Cloning into 'Multi_Layer_Perceptron'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 45 (delta 12), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (45/45), 2.02 MiB | 8.04 MiB/s, done.

# %%
# %cd /content/Multi_Layer_Perceptron
#코랩 탭의 파일구조 내에서 위에서 복제한 실습 자료가 있는 폴더로 이동한다.
#학술망에서 저장된 이미지를 출력하기 위해 필요한 코드이다.
# Out:
# /content/Multi_Layer_Perceptron

# %% [markdown]
# ## [1] 실습 진행 관련 설명
#
# - XOR 문제를 해결하는 XOR 게이트
#          1). 논리회로를 통한 구현 (Numpy)
#          2). Python 함수와 Tensorflow 함수를 활용한 다층 퍼셉트론 직접 구현
#          3). Tensorflow 라이브러리의 모듈을 활용한 간단한 구현

# %% [markdown]
# ## [2] 코드 구현의 흐름
#
#
#         1. (데이터 측면) XOR 입력 데이터 정의
#
#         2. (모델 측면) 가중치, 바이어스, 활성화 함수, 손실 함수 정의
#
#         3. (모델 및 학습 과정) 학습 과정을 직접 구현 또는 텐서플로우 라이브러리의 간단한 함수로 간접 구현하여 다층 퍼셉트론 모델을 학습
#         - 손실함수와 학습 데이터에 대한 정확도 그래프의 변화 관찰
#
#         4. (성능 평가) 테스트 데이터를 이용하여 학습된 모델에 대한 성능 평가하기.
#         - 최종 분류 정확도와 혼동 행렬

# %% [markdown]
# # 1. XOR 문제의 해결 방법 (MLP XOR Solution)

# %% [markdown]
# - XOR 문제 또한 0 또는 1 이진 분류 문제에 해당하며, 단층 퍼셉트론으로는 해결할 수 없는 특별한 케이스이다.
# - 두 입력 값이 서로 같으면 0, 서로 다르면 1로 분류하는 논리회로와 같다.

# %% [markdown]
# <img src="https://github.com/ballade8/Multi_Layer_Perceptron/blob/main/XORgate2.png?raw=true" width="600"/>

# %%
from PIL import Image # 이미지 출력 함수
Image.open("/content/Multi_Layer_Perceptron/XORgate2.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1556x617 at 0x7FC50D662950>

# %% [markdown]
# - 다층 퍼셉트론(Multi-layer Perceptron)
#   즉, 두개 이상의 선을 이용하기 위해 은닉층이 1개 이상 필요하다.

# %% [markdown]
# ## 1) XOR 게이트를 3개의 퍼셉트론을 이용하여 표현해보자.
# (NAND, OR, AND 게이트를 나타내기 위해서, 각 단층 퍼셉트론은 3개의 입력 노드(바이어스 포함)와 1개의 출력 노드로 구성되어 있다. 입력 노드와 출력 노드 사이에 가중치로 연결되어 있다. 출력 노드는 3개의 입력 노드와 각 대응되는 가중치의 곱의 합인 가중합과 활성화함수(ex. 계단함수)를 거쳐 출력한다.

# %% [markdown]
# <img src="https://github.com/ballade8/Multi_Layer_Perceptron/blob/main/XORgate.png?raw=true" width="600"/>

# %%
from PIL import Image # 이미지 출력 함수
Image.open("/content/Multi_Layer_Perceptron/XORgate.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1738x571 at 0x7FC50D662B00>

# %%
import numpy as np

w_nand = np.array([-2,-2]) # NAND의 동작을 하는 퍼셉트론의 가중치
w_or = np.array([2,2])     # OR의 동작을 하는 퍼셉트론의 가중치
w_and = np.array([1,1])    # AND의 동작을 하는 퍼셉트론의 가중치
bias_nand = 3              # NAND의 동작을 하는 퍼셉트론의 바이어스(w0)
bias_or = -1               # OR의 동작을 하는 퍼셉트론의 바이어스(w0)
bias_and = -1              # AND의 동작을 하는 퍼셉트론의 바이어스(w0)

# %%
def Perceptron(x,w,bias): # 퍼셉트론의 순전파의 과정을 잘 생각해보자
  z = np.sum(w*x)+bias   
  y_hat = z
  if y_hat <=0: # y 값이 0 이하면 return 0
    return 0
  else:	# y 값이 0 넘으면 return 1
    return 1

# %%
# NAND 게이트
def NAND(x1,x2):
  return Perceptron(np.array([x1,x2]),w_nand,bias_nand)

# OR 게이트
def OR(x1,x2):
  return Perceptron(np.array([x1,x2]),w_or,bias_or)

# AND 게이트
def AND(x1,x2):
  return Perceptron(np.array([x1,x2]),w_and,bias_and)

# XOR 게이트
def XOR(x1,x2):
  return AND(NAND(x1,x2),OR(x1,x2))

# %%
for x in [(0,0),(1,0),(0,1),(1,1)]: #학습되는 데이터의 형태를 잘 생각해보자
  y_hat = XOR(x[0],x[1]) # XOR동작은 위의 구현처럼 NAND OR AND 게이트 3개의 퍼셉트론을 이용하여 동작한다
  print("입력 값: "+ str(x)+ " 출력 값: "+ str(y_hat))

y = [(0, 1, 1, 0)]
y = np.array(y)
print("실제 값: "+ str(y) )
# Out:
# 입력 값: (0, 0) 출력 값: 0
# 입력 값: (1, 0) 출력 값: 1
# 입력 값: (0, 1) 출력 값: 1
# 입력 값: (1, 1) 출력 값: 0
# 실제 값: [[0]
#  [1]
#  [1]
#  [0]]

# %%
np.array([[0],[1],[1],[0]])
np.array([0,1,1,0])
# Out:
# array([0, 1, 1, 0])

# %% [markdown]
# ## 2) XOR 게이트를 다층 퍼셉트론 모델로 학습을 통해 구현하자.(직접 구현)
# (랜덤 초기값 가중치, Sigmoid 활성화 함수를 이용하여 적절한 가중치를 학습을 통해 스스로 찾음)

# %% [markdown]
# Multi-Layer Perceptron Architecture
#
# <img src="https://github.com/ballade8/Multi_Layer_Perceptron/blob/main/backporp22.png?raw=true" width="600"/>

# %%
from PIL import Image # 이미지 출력 함수
Image.open("/content/Multi_Layer_Perceptron/backporp22.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=845x473 at 0x7FC50D662920>

# %%
# 텐서플로우 활용
# 텐서플로우란 머신러닝 라이브러리의 일종으로 머신러닝, 딥러닝 등의 모델 구현을 좀 더 쉽게 구현할 수 있도록 도와주는 라이브러리이다.
# sklearn과 비슷하게 기계학습을 위한 함수들의 묶음으로 생각하자.
import tensorflow as tf
import matplotlib.pyplot as plt
tf.random.set_seed(2)
# seed를 설정하게 되면 random하게 뽑히는 값이 여러번 실행해도 동일한 값이 뽑히게 된다.
# 머신러닝 환경에서 중요한 요소 중 하나는 코드 실행했을 때 나오는 결과를 재현 할 수 있어야하는데, 해당 seed를 설정했을 때는 항상 동일한 값이 나오도록 설정해주는 것이다.
# seed를 변경해가며 random한 가중치의 초기값에 따라 결과가 어떻게 변하는지 확인해보자.

# %% [markdown]
# ### Tensorflow에 입력될 데이터 정의
# 먼저 학습 데이터 모양(shape)을 정의한다.
# XOR 학습 데이터에는 입력 X와 출력 Y가 있다다.
#
# X는 아래와 같이 [4,2] 형태로,
# [0, 0], [0, 1], [1, 0], [1, 1]
#
# Y는 아래와 같이 [4,1] 형태로,
# [[0], [1], [1], [0]]

# %%
# train data
# xor 데이터 전체 데이터를 하나의 리스트에 묶는다
X = [[0.,0.],[0.,1.],[1.,0.],[1.,1.]]
Y = [[0.],[1.],[1.],[0.]]

# %% [markdown]
# ### 첫번째 은닉층 구현

# %%
## tf.Variable 이란 TensorFlow 라이브러리에서 선언하는 변수로 tf.Variable(value, name, dtype, shape) 의 메소드를 사용해서 만든다.
### 모델 학습을 통해 변수는 새롭게 업데이트되기 때문에 가중치를 선언할 때 주로 사용

# 첫번째 은닉층 노드에서 가중합 연산을 수행하는 가중치들(0번째)을 랜덤한 값으로 초기화하여 정의한다.
W1_0 = tf.Variable(tf.random.uniform(shape=[2,2]))
# "print(W1_0)"으로 W1_0의 값을 확인해보자.
# 첫번째 은닉층 노드에서 가중합 연산을 수행하는 바이어스(0번째)를 선언한다
W0_0 = tf.Variable(tf.ones(shape=[2]))
# "print(W0_0)"으로 W0_0의 값을 확인해보자.
# 첫번째 은닉층의 가중합인 Z_1 의 연산은 다음과 같다.
Z_1 = tf.matmul(X, W1_0) + W0_0
# 여기서 X는 (4, 2)의 형태임에 주의하자.
# (4, 2)의 모양을 하고 있는 "tf.matmul(X, W1_0)"의 결과물에 
# (2,)의 모양을 하고 있는 "W0_0"을 더하면 브로드캐스팅에 의해
#  "tf.matmul(X, W1_0)"의 네 개의 행에 동일한 "W0_0"가 더해진다.
# 첫번째 은닉층 노드들의 활성화 함수를 거친 출력값 H_1 은 다음과 같다.
# 활성화 함수는 sigmoid function
H_1 = tf.sigmoid(Z_1)

# %% [markdown]
# ### 두번째 출력층 구현

# %%
# 두번째 출력층 노드에서 가중합 연산을 수행하는 가중치(1번째)를 랜덤한 값으로 초기화하여 정의한다
W1_1 = tf.Variable(tf.random.uniform([2,1]))
# 두번째 출력층 노드에서 가중합 연산을 수행하는 바이어스(1번째)를 선언한다
W0_1 = tf.Variable(tf.ones([1]))
# 두번째 출력층의 가중합인 Z_2 의 연산은 다음과 같다.
Z_2 = tf.matmul(H_1, W1_1) + W0_1
# 두번째 출력층 노드들의 활성화 함수를 거친 출력값 H_2=Y_hat 은 다음과 같다.
# 활성화 함수는 sigmoid function
Y_hat = tf.sigmoid(Z_2)

# %% [markdown]
# ### 손실함수를 정의
# - 바이너리 크로스 엔트로피(Binary Cross Entropy)

# %%
# 텐서플로우 라이브러리의 케라스 라이브러리로부터 BinaryCrossentropy 손실함수를 불러온다.
# 로지스틱 회귀 실습에서 이용한 적이 있는 손실함수이다.
# tensorflow의 keras가 제공하는 losses 패키지로부터 불러온 BinaryCrossentropy()를
# loss_object라고 호칭해주면 "tf.keras.losses.BinaryCrossentropy()"를 사용할 준비가 된 것이다.
loss_object = tf.keras.losses.BinaryCrossentropy()
loss = loss_object(Y, Y_hat)

# 참고로 손실함수를 풀어 쓰면 아래와 같다.
# tf.reduce_mean(-1*((Y*tf.math.log(Y_hat))+((1-Y)*tf.math.log(1.0-Y_hat))))

loss_list = []  
accuracy_list = []
# 학습이 반복될 때마다 계산된 발생한 오차와 모델의 정확도를 저장하기 위해 리스트를 선언한다

# %% [markdown]
# ### 가중치 업데이트
# - 텐서플로우 2.0 버전 이후부터 기본 최적화 기법을 SGD(Stochastic Gradient Descent)로 사용한다.
#
# - 경사 하강법은 정확하게 가중치를 찾아가지만 가중치를 변경할때마다 전체 데이터에 대해 미분해야 하므로 계산량이 매우 많다. 즉 많은 계산량때문에 속도가 느리고, 추가적으로 최적해를 찾기 전 로컬 미니멈에서 벗어나지 못하는 경우가 발생한다.
# - tf.train.GradientDescentOptimizer()  (구 버전 GradientDescentOptimizer 거의 사용하지 않음.)

# %% [markdown]
# **SGD (Stochastic Gradient Descent)**
#
# SGD는 전체 훈련 데이터 N개에 대하여 랜덤하게 섞는 다음에 각 1개 훈련 데이터씩에 대하여 경사하강법으로 가중치를 업데이트하는 학습 방법이다.
#
# Momentum(모멘텀)은 모델의 인자를 갱신할 때, 이제까지 학습했던 바와 같이 손실함수(목적함수)의 그레디언트만 활용하는 것이 아니라, 과거 계산된 그레디언트를 축적해서 활용하는 방법이라고 간단하게 이해하자. 수식으로 정의하면 보다 명확해지나, 인공지능입문에서 모멘텀의 수식적인 정의는 교육 범위를 벗어남.

# %%
## 확률적 경사 하강법(Stochastic Gradient Descent, SGD)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)

## 모든 훈련 데이터에 대하여 경사하강법으로 가중치를 업데이트 하는 것이 아니라, SGD는 전체 훈련 데이터를 랜덤하게 섞는 다음에 각 1개 훈련 데이터씩 경사하강법으로 가중치를 업데이트 한다. (전체 훈련데이터 N개를 1개씩 차례대로 경사하강법으로 가중치 업데이트를 반복)
## 경사 하강법의 한계점을 빠른속도와 함께 작은 반복횟수로 어느정도 극복 가능하다.

# 참고. Momentum(모멘텀) 계수를 추가로 활용할 수 있다
## 모멘텀(관성)은 경사하강법을 통해 가중치가 최적해로 이동하는 과정에서 일종의 '관성'을 부여하는 것이다. 장점으로는 적은 반복 회수로 가중치를 최적해로 수렴하기가 용이하고, 로컬 미니멈 문제를 일부 해결 할 수가 있다. 
## 여기서 최적해는 손실함수를 가장 최소화하는 지점에서의 가중치 값을 의미한다.

# %% [markdown]
# <img src="https://github.com/ballade8/Multi_Layer_Perceptron/blob/main/sgd_momentum.png?raw=true" width="600"/>

# %%
from PIL import Image # 이미지 출력 함수
Image.open("/content/Multi_Layer_Perceptron/sgd_momentum.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=904x350 at 0x7FC50D6E8610>

# %% [markdown]
# ### 학습 과정 구현

# %%
epoch = 2000
for i in range(epoch):  # 반복횟수 epoch를 바꿔서 학습을 추가로 진행할 수 있다
  # tensorflow의 GradientTape이 사용되었다.
  # 현재 코드셀에서는 "gradients = tape.gradient(loss, [W1_0, W0_0, W1_1, W0_1])"에서 사용되는데
  # 그 전에 "with tf.GradientTape() as tape"의 "with ~ as ~" 문을 살펴보자.
  # "with tf.GradientTape() as tape"에서는 tensorflow의 GradientTape()라는 구조("객체"라고 한다)를
  # 가져와서 활용하고자 한다. 이 개체에는 들여쓰기로 표현된 "H_1 = "부터 "accuracy = "까지의
  # 연산결과가 기록되고(이 연산은 다층퍼셉트론의 1회 순전파에 해당됨을 눈치채었는가?)
  # 해당 연산들이 종료되면 tape 객체가 다음 줄의 함수 연산에서 할용된다. 
    with tf.GradientTape() as tape:
        # 첫번째 은닉층에서의 순전파 연산의 출력
        H_1 = tf.sigmoid(tf.matmul(X, W1_0) + W0_0)
        # 두번째 출력층에서의 순전파 연산의 출력(최종 출력)
        Y_hat = tf.sigmoid(tf.matmul(H_1, W1_1) + W0_1)
        # 손실함수 연산, 위에서 정의했다.
        loss = loss_object(Y, Y_hat)
        # 학습데이터에 대한 정확도 연산
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.round(Y_hat), Y), dtype=tf.float32))
        ## Y와 Y_hat 값이 서로 일치하는지 여부를 cast 함수가 0(False) 또는 1(True)로 변환해준다.
        ## 변환된 결과들의 평균값(reduce_mean 함수)을 정확도로 사용할 수 있다.

    # 다층퍼셉트론의 순전파 연산이 종료되면
    # 아래 코드와 같이 tape에 저장된 연산 결과를 활용하여 그레디언트를 계산하는데
    # "tape.gradient(loss, [W1_0, W0_0, W1_1, W0_1])" 
    # 구체적으로 설명하면 "loss"값을 활용하여 W1_0, W0_0, W1_1, W0_1에 대한
    # 그레디언트를 계산하게 된다.
    # 그래디언트 연산
    gradients = tape.gradient(loss, [W1_0, W0_0, W1_1, W0_1])
    #optimizer을 통해 모델의 가중치 업데이트가 진행된다.
    # "zip"은 그레디언트 계산 결과와 W1_0, W0_0, W1_1, W0_1를 각각 쌍을 맺어준다.
    # W1_0와 이에 해당하는 그레디언트, W0_0와 이에 해당하는 그레디언트, 
    # W1_1와 이에 해당하는 그레디언트의 씩으로 쌍이 맺어진다고 이해하자.
    # 그 후 갱신하고 싶은 인자에 계산된 그레디언트를 "apply_gradients"를 적용하여
    # 실제로 계산한다.
    optimizer.apply_gradients(zip(gradients, [W1_0, W0_0, W1_1, W0_1]))
    
    # 학습된 결과를 100번째 epoch마다 출력해준다.
    if i % 100 == 0:
         print('Epoch : ', i)
         print('Output : ', Y_hat.numpy())
         print('Loss : ', loss.numpy())
         print('Accuracy : ', accuracy.numpy())

         loss_list.append(loss.numpy())  
         accuracy_list.append(accuracy.numpy())
         # 결과를 전부 리스트로 저장한다.
    
print('Final Output : ', Y_hat.numpy())
# Out:
# Epoch :  0
# Output :  [[0.89888066]
#  [0.9067219 ]
#  [0.9074564 ]
#  [0.91332996]]
# Loss :  1.233032
# Accuracy :  0.5
# Epoch :  100
# Output :  [[0.49451143]
#  [0.49678788]
#  [0.49870405]
#  [0.50061905]]
# Loss :  0.69298744
# Accuracy :  0.25
# Epoch :  200
# Output :  [[0.49524662]
#  [0.49966925]
#  [0.50181735]
#  [0.505382  ]]
# Loss :  0.69274557
# Accuracy :  0.5
# Epoch :  300
# Output :  [[0.4909087 ]
#  [0.5004833 ]
#  [0.50301695]
#  [0.5099602 ]]
# Loss :  0.6919271
# Accuracy :  0.75
# Epoch :  400
# Output :  [[0.4780162 ]
#  [0.50406295]
#  [0.5075992 ]
#  [0.52166444]]
# Loss :  0.6876695
# Accuracy :  0.75
# Epoch :  500
# Output :  [[0.42315885]
#  [0.52140516]
#  [0.52896464]
#  [0.55269873]]
# Loss :  0.660693
# Accuracy :  0.75
# Epoch :  600
# Output :  [[0.22706132]
#  [0.58131313]
#  [0.60642093]
#  [0.61071944]]
# Loss :  0.5609141
# Accuracy :  0.75
# Epoch :  700
# Output :  [[0.12637645]
#  [0.61163473]
#  [0.71927977]
#  [0.5674436 ]]
# Loss :  0.44856814
# Accuracy :  0.75
# Epoch :  800
# Output :  [[0.10906556]
#  [0.84076124]
#  [0.83865595]
#  [0.23590052]]
# Loss :  0.18348584
# Accuracy :  1.0
# Epoch :  900
# Output :  [[0.06435331]
#  [0.9347802 ]
#  [0.9343551 ]
#  [0.08349917]]
# Loss :  0.072262935
# Accuracy :  1.0
# Epoch :  1000
# Output :  [[0.04340496]
#  [0.9613482 ]
#  [0.9611211 ]
#  [0.04641369]]
# Loss :  0.04274336
# Accuracy :  1.0
# Epoch :  1100
# Output :  [[0.03245567]
#  [0.9728405 ]
#  [0.9726979 ]
#  [0.03149971]]
# Loss :  0.030054238
# Accuracy :  1.0
# Epoch :  1200
# Output :  [[0.02583355]
#  [0.9791576 ]
#  [0.97905874]
#  [0.02365086]]
# Loss :  0.023083486
# Accuracy :  1.0
# Epoch :  1300
# Output :  [[0.02142141]
#  [0.98312986]
#  [0.9830565 ]
#  [0.01885728]]
# Loss :  0.018698461
# Accuracy :  1.0
# Epoch :  1400
# Output :  [[0.01827955]
#  [0.9858503 ]
#  [0.98579323]
#  [0.01564268]]
# Loss :  0.015693495
# Accuracy :  1.0
# Epoch :  1500
# Output :  [[0.01593201]
#  [0.98782635]
#  [0.9877805 ]
#  [0.01334428]]
# Loss :  0.013509264
# Accuracy :  1.0
# Epoch :  1600
# Output :  [[0.01411311]
#  [0.98932505]
#  [0.9892872 ]
#  [0.01162286]]
# Loss :  0.011851761
# Accuracy :  1.0
# Epoch :  1700
# Output :  [[0.01266329]
#  [0.9904997 ]
#  [0.9904677 ]
#  [0.01028726]]
# Loss :  0.0105519965
# Accuracy :  1.0
# Epoch :  1800
# Output :  [[0.01148115]
#  [0.99144447]
#  [0.9914171 ]
#  [0.00922191]]
# Loss :  0.009506019
# Accuracy :  1.0
# Epoch :  1900
# Output :  [[0.01049914]
#  [0.99222046]
#  [0.99219674]
#  [0.00835299]]
# Loss :  0.008646511
# Accuracy :  1.0
# Final Output :  [[0.00967823]
#  [0.9928631 ]
#  [0.9928422 ]
#  [0.00763772]]

# %%
# epoch 별로 저장된 loss와 정확도를 출력해주는 그래프를 시각화한다.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.plot(loss_list) # 모델의 오차
ax1.set_title('Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax2.plot(accuracy_list) # 모델의 정확도
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
plt.show()

# %% [markdown]
# ## 3). XOR 게이트를 Tensorflow 2.0, Keras를 활용해서 간단하게 구현하자.
# - 장점 : 코드가 짧아짐. 모델 요약(Model Summary) 및 시각화(Visualization)
# - Multi-Layer Perceptron Architecture (2)번과 동일한 구현
#
#
#
#
# <img src="https://github.com/ballade8/Multi_Layer_Perceptron/blob/main/backporp22.png?raw=true" width="600"/>

# %%
# 우리가 배운 대부분의 이론 내용들이 Tensorflow와 같은 라이브러리에서 간편한 명령어로 구현되어 있다.
# tensorflow.keras 라이브러리로부터 주요 기능을 가져다가 간편하게 사용해보자.

import tensorflow as tf # tf로 짧게 선언
from tensorflow.keras.layers import Input, Dense # 모델의 세부구성과 관련된 함수
from tensorflow.keras.models import Model # 모델을 정의하는 함수
from tensorflow.keras.optimizers import SGD # 경사하강법 함수
from tensorflow.keras.losses import BinaryCrossentropy # 손실함수 정의
from tensorflow.keras.utils import plot_model # 시각화 함수

# %% [markdown]
# ### 입력데이터 정의 : train data

# %%
#학습 데이터 선언
#XOR 데이터
train__X = [[0,0],[0,1],[1,0],[1,1]]
train_Y = [[0],[1],[1],[0]]

# %% [markdown]
# ### 모델 구축

# %%
#입력층  
## 특징벡터의 성분 개수
inputs = Input(shape=(2,))

#은닉층 1개, 은닉노드 2개(바이어스 노드 제외)
## 은닉층의 구성은 사용자가 마음대로 구성할 수 있다. 그 대신 많을수록 연산량이 증가한다.
hidden_layer = Dense(2, activation='sigmoid')(inputs)
## Dense 함수는 텐서플로우의 다층 퍼셉트론 모델에서 은닉층과 출력층의 노드를 선언할 때 쓰이는 함수이다.

#출력층  
## 실제값의 성분 개수
output_layer = Dense(1, activation='sigmoid')(hidden_layer)

# Model 함수는 텐서플로우에서 모델의 형태를 선언하는 함수이다.
model = Model(inputs=inputs, outputs=output_layer)

# %% [markdown]
# ### 옵티마이저와 손실함수 정의

# %%
optimizer = SGD(learning_rate=0.02, momentum=0.9)
# 2)번의 직접 구현한 코드에서 등장하여 설명한 SGD와 모멘텀을 사용한다.

loss_object = BinaryCrossentropy()
# 손실함수를 정의한다.

# %% [markdown]
# ### 모델에 필요한 추가 인자를 조립(컴파일)

# %%
model.compile(optimizer=optimizer, loss=loss_object, metrics=['accuracy'])
#위에서 정의한 학습에 사용되어야할 옵티마이저, 손실함수, 모델 성능 지표를 모델의 인자로 조립(컴파일)해준다.

# %% [markdown]
# ### 구축이 완료된 모델을 요약

# %%
model.summary()
#구축이 완료된 모델의 형태를 확인 가능
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
#구축이 완료된 모델의 형태를 그림으로 도식화 가능
plot_model(model, show_shapes=True, show_dtype=True, show_layer_names=True, show_layer_activations=True, show_trainable=True)
# 여기서 T의 의미는 trainable true 이다.
# 아래 위의 실행 결과에서 "None"은 입력으로 제공될 관측값의 수가 사전에 제한되지 않아서
# 2개의 성분으로 구성된 입력값(특징 벡터)를 여러 개 제공할 수 있다는 의미로 이해하자.

# %% [markdown]
# ### 모델 학습 과정

# %%
history = model.fit(train__X, train_Y, epochs=2000, batch_size=3)
# 여러분이 epoch를 조절할 수 있다, history로 학습을 정의하여 다음에 나올 시각화 코드로 학습 과정을 표현해보자.
history
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 1s 9ms/step - loss: 0.7402 - accuracy: 0.5000
# Epoch 2/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7331 - accuracy: 0.5000
# Epoch 3/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7220 - accuracy: 0.5000
# Epoch 4/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7096 - accuracy: 0.5000
# Epoch 5/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6986 - accuracy: 0.5000
# Epoch 6/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6910 - accuracy: 0.5000
# Epoch 7/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6878 - accuracy: 0.5000
# Epoch 8/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6895 - accuracy: 0.5000
# Epoch 9/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6955 - accuracy: 0.5000
# Epoch 10/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7050 - accuracy: 0.5000
# Epoch 11/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7167 - accuracy: 0.5000
# Epoch 12/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7294 - accuracy: 0.5000
# Epoch 13/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7422 - accuracy: 0.5000
# Epoch 14/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7541 - accuracy: 0.5000
# Epoch 15/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7646 - accuracy: 0.5000
# Epoch 16/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7734 - accuracy: 0.5000
# Epoch 17/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7802 - accuracy: 0.5000
# Epoch 18/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7852 - accuracy: 0.5000
# Epoch 19/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7884 - accuracy: 0.5000
# Epoch 20/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7900 - accuracy: 0.5000
# Epoch 21/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7903 - accuracy: 0.5000
# Epoch 22/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7894 - accuracy: 0.5000
# Epoch 23/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7877 - accuracy: 0.5000
# Epoch 24/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7854 - accuracy: 0.5000
# Epoch 25/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7827 - accuracy: 0.5000
# Epoch 26/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7797 - accuracy: 0.5000
# Epoch 27/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7766 - accuracy: 0.5000
# Epoch 28/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7735 - accuracy: 0.5000
# Epoch 29/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7706 - accuracy: 0.5000
# Epoch 30/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7678 - accuracy: 0.5000
# Epoch 31/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7653 - accuracy: 0.5000
# Epoch 32/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7630 - accuracy: 0.5000
# Epoch 33/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7610 - accuracy: 0.5000
# Epoch 34/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7592 - accuracy: 0.5000
# Epoch 35/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7578 - accuracy: 0.5000
# Epoch 36/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7566 - accuracy: 0.5000
# Epoch 37/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7556 - accuracy: 0.5000
# Epoch 38/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7548 - accuracy: 0.5000
# Epoch 39/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7542 - accuracy: 0.5000
# Epoch 40/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7538 - accuracy: 0.5000
# Epoch 41/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7536 - accuracy: 0.5000
# Epoch 42/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7534 - accuracy: 0.5000
# Epoch 43/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7534 - accuracy: 0.5000
# Epoch 44/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7535 - accuracy: 0.5000
# Epoch 45/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7536 - accuracy: 0.5000
# Epoch 46/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7537 - accuracy: 0.5000
# Epoch 47/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7539 - accuracy: 0.5000
# Epoch 48/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7541 - accuracy: 0.5000
# Epoch 49/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7543 - accuracy: 0.5000
# Epoch 50/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7545 - accuracy: 0.5000
# Epoch 51/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7547 - accuracy: 0.5000
# Epoch 52/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7549 - accuracy: 0.5000
# Epoch 53/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7550 - accuracy: 0.5000
# Epoch 54/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7552 - accuracy: 0.5000
# Epoch 55/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7552 - accuracy: 0.5000
# Epoch 56/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7553 - accuracy: 0.5000
# Epoch 57/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7554 - accuracy: 0.5000
# Epoch 58/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7554 - accuracy: 0.5000
# Epoch 59/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7554 - accuracy: 0.5000
# Epoch 60/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7553 - accuracy: 0.5000
# Epoch 61/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7553 - accuracy: 0.5000
# Epoch 62/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7552 - accuracy: 0.5000
# Epoch 63/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7551 - accuracy: 0.5000
# Epoch 64/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7550 - accuracy: 0.5000
# Epoch 65/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7549 - accuracy: 0.5000
# Epoch 66/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7548 - accuracy: 0.5000
# Epoch 67/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7547 - accuracy: 0.5000
# Epoch 68/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7546 - accuracy: 0.5000
# Epoch 69/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7545 - accuracy: 0.5000
# Epoch 70/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7544 - accuracy: 0.5000
# Epoch 71/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7542 - accuracy: 0.5000
# Epoch 72/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7541 - accuracy: 0.5000
# Epoch 73/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7540 - accuracy: 0.5000
# Epoch 74/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7539 - accuracy: 0.5000
# Epoch 75/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7537 - accuracy: 0.5000
# Epoch 76/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7536 - accuracy: 0.5000
# Epoch 77/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7535 - accuracy: 0.5000
# Epoch 78/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7534 - accuracy: 0.5000
# Epoch 79/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7533 - accuracy: 0.5000
# Epoch 80/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7532 - accuracy: 0.5000
# Epoch 81/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7530 - accuracy: 0.5000
# Epoch 82/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7529 - accuracy: 0.5000
# Epoch 83/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7528 - accuracy: 0.5000
# Epoch 84/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7527 - accuracy: 0.5000
# Epoch 85/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7526 - accuracy: 0.5000
# Epoch 86/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7525 - accuracy: 0.5000
# Epoch 87/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7524 - accuracy: 0.5000
# Epoch 88/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7523 - accuracy: 0.5000
# Epoch 89/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7521 - accuracy: 0.5000
# Epoch 90/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7520 - accuracy: 0.5000
# Epoch 91/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7519 - accuracy: 0.5000
# Epoch 92/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7518 - accuracy: 0.5000
# Epoch 93/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7517 - accuracy: 0.5000
# Epoch 94/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7515 - accuracy: 0.5000
# Epoch 95/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7514 - accuracy: 0.5000
# Epoch 96/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7513 - accuracy: 0.5000
# Epoch 97/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7512 - accuracy: 0.5000
# Epoch 98/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7510 - accuracy: 0.5000
# Epoch 99/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7509 - accuracy: 0.5000
# Epoch 100/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7508 - accuracy: 0.5000
# Epoch 101/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7506 - accuracy: 0.5000
# Epoch 102/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7505 - accuracy: 0.5000
# Epoch 103/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7503 - accuracy: 0.5000
# Epoch 104/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7502 - accuracy: 0.5000
# Epoch 105/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7500 - accuracy: 0.5000
# Epoch 106/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7499 - accuracy: 0.5000
# Epoch 107/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7497 - accuracy: 0.5000
# Epoch 108/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7496 - accuracy: 0.5000
# Epoch 109/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7494 - accuracy: 0.5000
# Epoch 110/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7492 - accuracy: 0.5000
# Epoch 111/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7491 - accuracy: 0.5000
# Epoch 112/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7489 - accuracy: 0.5000
# Epoch 113/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7487 - accuracy: 0.5000
# Epoch 114/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7486 - accuracy: 0.5000
# Epoch 115/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7484 - accuracy: 0.5000
# Epoch 116/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7482 - accuracy: 0.5000
# Epoch 117/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7480 - accuracy: 0.5000
# Epoch 118/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7479 - accuracy: 0.5000
# Epoch 119/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7477 - accuracy: 0.5000
# Epoch 120/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7475 - accuracy: 0.5000
# Epoch 121/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7473 - accuracy: 0.5000
# Epoch 122/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7471 - accuracy: 0.5000
# Epoch 123/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7469 - accuracy: 0.5000
# Epoch 124/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7467 - accuracy: 0.5000
# Epoch 125/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7465 - accuracy: 0.5000
# Epoch 126/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7463 - accuracy: 0.5000
# Epoch 127/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7461 - accuracy: 0.5000
# Epoch 128/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7459 - accuracy: 0.5000
# Epoch 129/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7457 - accuracy: 0.5000
# Epoch 130/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7454 - accuracy: 0.5000
# Epoch 131/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7452 - accuracy: 0.5000
# Epoch 132/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7450 - accuracy: 0.5000
# Epoch 133/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7448 - accuracy: 0.5000
# Epoch 134/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7445 - accuracy: 0.5000
# Epoch 135/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7443 - accuracy: 0.5000
# Epoch 136/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7440 - accuracy: 0.5000
# Epoch 137/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7438 - accuracy: 0.5000
# Epoch 138/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7436 - accuracy: 0.5000
# Epoch 139/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7433 - accuracy: 0.5000
# Epoch 140/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7430 - accuracy: 0.5000
# Epoch 141/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7428 - accuracy: 0.5000
# Epoch 142/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7425 - accuracy: 0.5000
# Epoch 143/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7423 - accuracy: 0.5000
# Epoch 144/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7420 - accuracy: 0.5000
# Epoch 145/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7417 - accuracy: 0.5000
# Epoch 146/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7414 - accuracy: 0.5000
# Epoch 147/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7412 - accuracy: 0.5000
# Epoch 148/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7409 - accuracy: 0.5000
# Epoch 149/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7406 - accuracy: 0.5000
# Epoch 150/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7403 - accuracy: 0.5000
# Epoch 151/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7400 - accuracy: 0.5000
# Epoch 152/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7397 - accuracy: 0.5000
# Epoch 153/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7394 - accuracy: 0.5000
# Epoch 154/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7391 - accuracy: 0.5000
# Epoch 155/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7388 - accuracy: 0.5000
# Epoch 156/2000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7385 - accuracy: 0.5000
# Epoch 157/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7381 - accuracy: 0.5000
# Epoch 158/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7378 - accuracy: 0.5000
# Epoch 159/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7375 - accuracy: 0.5000
# Epoch 160/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7371 - accuracy: 0.5000
# Epoch 161/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7368 - accuracy: 0.5000
# Epoch 162/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7365 - accuracy: 0.5000
# Epoch 163/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7361 - accuracy: 0.5000
# Epoch 164/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7358 - accuracy: 0.5000
# Epoch 165/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7354 - accuracy: 0.5000
# Epoch 166/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7351 - accuracy: 0.5000
# Epoch 167/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7347 - accuracy: 0.5000
# Epoch 168/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7343 - accuracy: 0.5000
# Epoch 169/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7340 - accuracy: 0.5000
# Epoch 170/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7336 - accuracy: 0.5000
# Epoch 171/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7332 - accuracy: 0.5000
# Epoch 172/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7328 - accuracy: 0.5000
# Epoch 173/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7324 - accuracy: 0.5000
# Epoch 174/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7320 - accuracy: 0.5000
# Epoch 175/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7317 - accuracy: 0.5000
# Epoch 176/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7313 - accuracy: 0.5000
# Epoch 177/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7308 - accuracy: 0.5000
# Epoch 178/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7304 - accuracy: 0.5000
# Epoch 179/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7300 - accuracy: 0.5000
# Epoch 180/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7296 - accuracy: 0.5000
# Epoch 181/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7292 - accuracy: 0.5000
# Epoch 182/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7288 - accuracy: 0.5000
# Epoch 183/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7283 - accuracy: 0.5000
# Epoch 184/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7279 - accuracy: 0.5000
# Epoch 185/2000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7275 - accuracy: 0.5000
# Epoch 186/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7270 - accuracy: 0.5000
# Epoch 187/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7266 - accuracy: 0.5000
# Epoch 188/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7261 - accuracy: 0.5000
# Epoch 189/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7257 - accuracy: 0.5000
# Epoch 190/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7252 - accuracy: 0.5000
# Epoch 191/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7247 - accuracy: 0.5000
# Epoch 192/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7243 - accuracy: 0.5000
# Epoch 193/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7238 - accuracy: 0.5000
# Epoch 194/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7233 - accuracy: 0.5000
# Epoch 195/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7228 - accuracy: 0.5000
# Epoch 196/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7223 - accuracy: 0.5000
# Epoch 197/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7219 - accuracy: 0.5000
# Epoch 198/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7214 - accuracy: 0.5000
# Epoch 199/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7209 - accuracy: 0.5000
# Epoch 200/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7204 - accuracy: 0.5000
# Epoch 201/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7198 - accuracy: 0.5000
# Epoch 202/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7193 - accuracy: 0.5000
# Epoch 203/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7188 - accuracy: 0.5000
# Epoch 204/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7183 - accuracy: 0.5000
# Epoch 205/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7178 - accuracy: 0.5000
# Epoch 206/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7172 - accuracy: 0.5000
# Epoch 207/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7167 - accuracy: 0.5000
# Epoch 208/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7162 - accuracy: 0.5000
# Epoch 209/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7156 - accuracy: 0.5000
# Epoch 210/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7151 - accuracy: 0.5000
# Epoch 211/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7145 - accuracy: 0.5000
# Epoch 212/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7140 - accuracy: 0.5000
# Epoch 213/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7134 - accuracy: 0.5000
# Epoch 214/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7129 - accuracy: 0.5000
# Epoch 215/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7123 - accuracy: 0.5000
# Epoch 216/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7117 - accuracy: 0.5000
# Epoch 217/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7111 - accuracy: 0.5000
# Epoch 218/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7106 - accuracy: 0.5000
# Epoch 219/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7100 - accuracy: 0.5000
# Epoch 220/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7094 - accuracy: 0.5000
# Epoch 221/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7088 - accuracy: 0.5000
# Epoch 222/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7082 - accuracy: 0.5000
# Epoch 223/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7076 - accuracy: 0.5000
# Epoch 224/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7070 - accuracy: 0.5000
# Epoch 225/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.7064 - accuracy: 0.5000
# Epoch 226/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7058 - accuracy: 0.5000
# Epoch 227/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7052 - accuracy: 0.5000
# Epoch 228/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7045 - accuracy: 0.5000
# Epoch 229/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7039 - accuracy: 0.5000
# Epoch 230/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7033 - accuracy: 0.5000
# Epoch 231/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7026 - accuracy: 0.5000
# Epoch 232/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7020 - accuracy: 0.5000
# Epoch 233/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7014 - accuracy: 0.5000
# Epoch 234/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7007 - accuracy: 0.5000
# Epoch 235/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7001 - accuracy: 0.5000
# Epoch 236/2000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6994 - accuracy: 0.5000
# Epoch 237/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6988 - accuracy: 0.5000
# Epoch 238/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6981 - accuracy: 0.5000
# Epoch 239/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6974 - accuracy: 0.5000
# Epoch 240/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6968 - accuracy: 0.5000
# Epoch 241/2000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6961 - accuracy: 0.5000
# Epoch 242/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6954 - accuracy: 0.5000
# Epoch 243/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6948 - accuracy: 0.5000
# Epoch 244/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6941 - accuracy: 0.2500
# Epoch 245/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934 - accuracy: 0.2500
# Epoch 246/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6927 - accuracy: 0.2500
# Epoch 247/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6920 - accuracy: 0.2500
# Epoch 248/2000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6913 - accuracy: 0.2500
# Epoch 249/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6906 - accuracy: 0.2500
# Epoch 250/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6899 - accuracy: 0.2500
# Epoch 251/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6892 - accuracy: 0.2500
# Epoch 252/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6885 - accuracy: 0.2500
# Epoch 253/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6878 - accuracy: 0.2500
# Epoch 254/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6871 - accuracy: 0.2500
# Epoch 255/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6864 - accuracy: 0.2500
# Epoch 256/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6857 - accuracy: 0.2500
# Epoch 257/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6850 - accuracy: 0.2500
# Epoch 258/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6842 - accuracy: 0.2500
# Epoch 259/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6835 - accuracy: 0.2500
# Epoch 260/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6828 - accuracy: 0.2500
# Epoch 261/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6820 - accuracy: 0.2500
# Epoch 262/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6813 - accuracy: 0.2500
# Epoch 263/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6806 - accuracy: 0.2500
# Epoch 264/2000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6798 - accuracy: 0.2500
# Epoch 265/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6791 - accuracy: 0.2500
# Epoch 266/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6784 - accuracy: 0.2500
# Epoch 267/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6776 - accuracy: 0.2500
# Epoch 268/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6769 - accuracy: 0.2500
# Epoch 269/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6761 - accuracy: 0.2500
# Epoch 270/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6754 - accuracy: 0.2500
# Epoch 271/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6746 - accuracy: 0.2500
# Epoch 272/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6739 - accuracy: 0.2500
# Epoch 273/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6731 - accuracy: 0.2500
# Epoch 274/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6724 - accuracy: 0.2500
# Epoch 275/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6716 - accuracy: 0.2500
# Epoch 276/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6709 - accuracy: 0.2500
# Epoch 277/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6701 - accuracy: 0.2500
# Epoch 278/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6693 - accuracy: 0.2500
# Epoch 279/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6686 - accuracy: 0.2500
# Epoch 280/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6678 - accuracy: 0.2500
# Epoch 281/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6671 - accuracy: 0.2500
# Epoch 282/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6663 - accuracy: 0.2500
# Epoch 283/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6655 - accuracy: 0.2500
# Epoch 284/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6648 - accuracy: 0.2500
# Epoch 285/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6640 - accuracy: 0.2500
# Epoch 286/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6632 - accuracy: 0.2500
# Epoch 287/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6625 - accuracy: 0.2500
# Epoch 288/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6617 - accuracy: 0.2500
# Epoch 289/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6609 - accuracy: 0.2500
# Epoch 290/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6602 - accuracy: 0.2500
# Epoch 291/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6594 - accuracy: 0.2500
# Epoch 292/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6586 - accuracy: 0.2500
# Epoch 293/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6579 - accuracy: 0.2500
# Epoch 294/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6571 - accuracy: 0.2500
# Epoch 295/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6563 - accuracy: 0.2500
# Epoch 296/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6556 - accuracy: 0.2500
# Epoch 297/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6548 - accuracy: 0.2500
# Epoch 298/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6540 - accuracy: 0.2500
# Epoch 299/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6533 - accuracy: 0.2500
# Epoch 300/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6525 - accuracy: 0.2500
# Epoch 301/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6517 - accuracy: 0.2500
# Epoch 302/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6510 - accuracy: 0.2500
# Epoch 303/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6502 - accuracy: 0.2500
# Epoch 304/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6495 - accuracy: 0.2500
# Epoch 305/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6487 - accuracy: 0.2500
# Epoch 306/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6479 - accuracy: 0.2500
# Epoch 307/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6472 - accuracy: 0.2500
# Epoch 308/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6464 - accuracy: 0.2500
# Epoch 309/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6457 - accuracy: 0.2500
# Epoch 310/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6449 - accuracy: 0.2500
# Epoch 311/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6442 - accuracy: 0.2500
# Epoch 312/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6434 - accuracy: 0.2500
# Epoch 313/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6426 - accuracy: 0.2500
# Epoch 314/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6419 - accuracy: 0.2500
# Epoch 315/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6412 - accuracy: 0.2500
# Epoch 316/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6404 - accuracy: 0.2500
# Epoch 317/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6397 - accuracy: 0.2500
# Epoch 318/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6389 - accuracy: 0.2500
# Epoch 319/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6382 - accuracy: 0.2500
# Epoch 320/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6374 - accuracy: 0.2500
# Epoch 321/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6367 - accuracy: 0.2500
# Epoch 322/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6360 - accuracy: 0.2500
# Epoch 323/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6352 - accuracy: 0.2500
# Epoch 324/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6345 - accuracy: 0.2500
# Epoch 325/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6338 - accuracy: 0.5000
# Epoch 326/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6330 - accuracy: 0.5000
# Epoch 327/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6323 - accuracy: 0.5000
# Epoch 328/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6316 - accuracy: 0.5000
# Epoch 329/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6309 - accuracy: 0.5000
# Epoch 330/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6301 - accuracy: 0.5000
# Epoch 331/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6294 - accuracy: 0.5000
# Epoch 332/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6287 - accuracy: 0.5000
# Epoch 333/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6280 - accuracy: 0.5000
# Epoch 334/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6273 - accuracy: 0.5000
# Epoch 335/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6266 - accuracy: 0.5000
# Epoch 336/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6259 - accuracy: 0.5000
# Epoch 337/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6252 - accuracy: 0.5000
# Epoch 338/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6245 - accuracy: 0.5000
# Epoch 339/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6238 - accuracy: 0.5000
# Epoch 340/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6231 - accuracy: 0.5000
# Epoch 341/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6224 - accuracy: 0.5000
# Epoch 342/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6217 - accuracy: 0.5000
# Epoch 343/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6210 - accuracy: 0.5000
# Epoch 344/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6203 - accuracy: 0.5000
# Epoch 345/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6197 - accuracy: 0.5000
# Epoch 346/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6190 - accuracy: 0.5000
# Epoch 347/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6183 - accuracy: 0.5000
# Epoch 348/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6176 - accuracy: 0.5000
# Epoch 349/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6170 - accuracy: 0.5000
# Epoch 350/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6163 - accuracy: 0.5000
# Epoch 351/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6156 - accuracy: 0.5000
# Epoch 352/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6150 - accuracy: 0.5000
# Epoch 353/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6143 - accuracy: 0.5000
# Epoch 354/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6137 - accuracy: 0.5000
# Epoch 355/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6130 - accuracy: 0.5000
# Epoch 356/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6124 - accuracy: 0.5000
# Epoch 357/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6117 - accuracy: 0.5000
# Epoch 358/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6111 - accuracy: 0.5000
# Epoch 359/2000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6104 - accuracy: 0.5000
# Epoch 360/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6098 - accuracy: 0.5000
# Epoch 361/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6092 - accuracy: 0.5000
# Epoch 362/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6085 - accuracy: 0.5000
# Epoch 363/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6079 - accuracy: 0.5000
# Epoch 364/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6073 - accuracy: 0.5000
# Epoch 365/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6067 - accuracy: 0.5000
# Epoch 366/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6061 - accuracy: 0.5000
# Epoch 367/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6054 - accuracy: 0.5000
# Epoch 368/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6048 - accuracy: 0.5000
# Epoch 369/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6042 - accuracy: 0.5000
# Epoch 370/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6036 - accuracy: 0.5000
# Epoch 371/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6030 - accuracy: 0.5000
# Epoch 372/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6024 - accuracy: 0.5000
# Epoch 373/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6018 - accuracy: 0.5000
# Epoch 374/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6012 - accuracy: 0.5000
# Epoch 375/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6006 - accuracy: 0.5000
# Epoch 376/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6001 - accuracy: 0.5000
# Epoch 377/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5995 - accuracy: 0.5000
# Epoch 378/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5989 - accuracy: 0.5000
# Epoch 379/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5983 - accuracy: 0.5000
# Epoch 380/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5977 - accuracy: 0.5000
# Epoch 381/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5972 - accuracy: 0.5000
# Epoch 382/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5966 - accuracy: 0.5000
# Epoch 383/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5960 - accuracy: 0.5000
# Epoch 384/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5955 - accuracy: 0.5000
# Epoch 385/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5949 - accuracy: 0.5000
# Epoch 386/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5944 - accuracy: 0.5000
# Epoch 387/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5938 - accuracy: 0.5000
# Epoch 388/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5933 - accuracy: 0.5000
# Epoch 389/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5927 - accuracy: 0.5000
# Epoch 390/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5922 - accuracy: 0.5000
# Epoch 391/2000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5916 - accuracy: 0.5000
# Epoch 392/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5911 - accuracy: 0.5000
# Epoch 393/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5906 - accuracy: 0.5000
# Epoch 394/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5900 - accuracy: 0.5000
# Epoch 395/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5895 - accuracy: 0.5000
# Epoch 396/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5890 - accuracy: 0.5000
# Epoch 397/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5885 - accuracy: 0.5000
# Epoch 398/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5880 - accuracy: 0.5000
# Epoch 399/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5874 - accuracy: 0.5000
# Epoch 400/2000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5869 - accuracy: 0.5000
# Epoch 401/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5864 - accuracy: 0.5000
# Epoch 402/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5859 - accuracy: 0.5000
# Epoch 403/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5854 - accuracy: 0.5000
# Epoch 404/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5849 - accuracy: 0.5000
# Epoch 405/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5844 - accuracy: 0.7500
# Epoch 406/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5839 - accuracy: 0.7500
# Epoch 407/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5834 - accuracy: 0.7500
# Epoch 408/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5829 - accuracy: 0.7500
# Epoch 409/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5825 - accuracy: 0.7500
# Epoch 410/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5820 - accuracy: 0.7500
# Epoch 411/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5815 - accuracy: 0.7500
# Epoch 412/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5810 - accuracy: 0.7500
# Epoch 413/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5806 - accuracy: 0.7500
# Epoch 414/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5801 - accuracy: 0.7500
# Epoch 415/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5796 - accuracy: 0.7500
# Epoch 416/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5791 - accuracy: 0.7500
# Epoch 417/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5787 - accuracy: 0.7500
# Epoch 418/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5782 - accuracy: 0.7500
# Epoch 419/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5778 - accuracy: 0.7500
# Epoch 420/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5773 - accuracy: 0.7500
# Epoch 421/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5769 - accuracy: 0.7500
# Epoch 422/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5764 - accuracy: 0.7500
# Epoch 423/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5760 - accuracy: 0.7500
# Epoch 424/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5755 - accuracy: 0.7500
# Epoch 425/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5751 - accuracy: 0.7500
# Epoch 426/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5747 - accuracy: 0.7500
# Epoch 427/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5742 - accuracy: 0.7500
# Epoch 428/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5738 - accuracy: 0.7500
# Epoch 429/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5734 - accuracy: 0.7500
# Epoch 430/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5729 - accuracy: 0.7500
# Epoch 431/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5725 - accuracy: 0.7500
# Epoch 432/2000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5721 - accuracy: 0.7500
# Epoch 433/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5717 - accuracy: 0.7500
# Epoch 434/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5712 - accuracy: 0.7500
# Epoch 435/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5708 - accuracy: 0.7500
# Epoch 436/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5704 - accuracy: 0.7500
# Epoch 437/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5700 - accuracy: 0.7500
# Epoch 438/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5696 - accuracy: 0.7500
# Epoch 439/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5692 - accuracy: 0.7500
# Epoch 440/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5688 - accuracy: 0.7500
# Epoch 441/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5684 - accuracy: 0.7500
# Epoch 442/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5680 - accuracy: 0.7500
# Epoch 443/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5676 - accuracy: 0.7500
# Epoch 444/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5672 - accuracy: 0.7500
# Epoch 445/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5668 - accuracy: 0.7500
# Epoch 446/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5664 - accuracy: 0.7500
# Epoch 447/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5661 - accuracy: 0.7500
# Epoch 448/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5657 - accuracy: 0.7500
# Epoch 449/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5653 - accuracy: 0.7500
# Epoch 450/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5649 - accuracy: 0.7500
# Epoch 451/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5645 - accuracy: 0.7500
# Epoch 452/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5642 - accuracy: 0.7500
# Epoch 453/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5638 - accuracy: 0.7500
# Epoch 454/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5634 - accuracy: 0.7500
# Epoch 455/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5630 - accuracy: 0.7500
# Epoch 456/2000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5627 - accuracy: 0.7500
# Epoch 457/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5623 - accuracy: 0.7500
# Epoch 458/2000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5620 - accuracy: 0.7500
# Epoch 459/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5616 - accuracy: 0.7500
# Epoch 460/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5612 - accuracy: 0.7500
# Epoch 461/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5609 - accuracy: 0.7500
# Epoch 462/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5605 - accuracy: 0.7500
# Epoch 463/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5602 - accuracy: 0.7500
# Epoch 464/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5598 - accuracy: 0.7500
# Epoch 465/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5595 - accuracy: 0.7500
# Epoch 466/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5591 - accuracy: 0.7500
# Epoch 467/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5588 - accuracy: 0.7500
# Epoch 468/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5585 - accuracy: 0.7500
# Epoch 469/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5581 - accuracy: 0.7500
# Epoch 470/2000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5578 - accuracy: 0.7500
# Epoch 471/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5575 - accuracy: 0.7500
# Epoch 472/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5571 - accuracy: 0.7500
# Epoch 473/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5568 - accuracy: 0.7500
# Epoch 474/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5565 - accuracy: 0.7500
# Epoch 475/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5561 - accuracy: 0.7500
# Epoch 476/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5558 - accuracy: 0.7500
# Epoch 477/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5555 - accuracy: 0.7500
# Epoch 478/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5552 - accuracy: 0.7500
# Epoch 479/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5548 - accuracy: 0.7500
# Epoch 480/2000
# ...
# Epoch 1843/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 1844/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 1845/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 1846/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 1847/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 1848/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 1849/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 1850/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 1851/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 1852/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 1853/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 1854/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 1855/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 1856/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 1857/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 1858/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 1859/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 1860/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 1861/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 1862/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 1863/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 1864/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 1865/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 1866/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 1867/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 1868/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 1869/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 1870/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 1871/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 1872/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 1873/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 1874/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 1875/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 1876/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 1877/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 1878/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 1879/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 1880/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 1881/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 1882/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 1883/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 1884/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 1885/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 1886/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 1887/2000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 1888/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 1889/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 1890/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 1891/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 1892/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 1893/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 1894/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 1895/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 1896/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 1897/2000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 1898/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 1899/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 1900/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 1901/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 1902/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 1903/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 1904/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 1905/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 1906/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 1907/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 1908/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 1909/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 1910/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 1911/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 1912/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 1913/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 1914/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 1915/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 1916/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 1917/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 1918/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 1919/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 1920/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 1921/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 1922/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 1923/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 1924/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 1925/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 1926/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 1927/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 1928/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 1929/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 1930/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 1931/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 1932/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 1933/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 1934/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 1935/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 1936/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 1937/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 1938/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 1939/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 1940/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 1941/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 1942/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 1943/2000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 1944/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 1945/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 1946/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 1947/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 1948/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 1949/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 1950/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 1951/2000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 1952/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 1953/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 1954/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 1955/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 1956/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 1957/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 1958/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 1959/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 1960/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 1961/2000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 1962/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 1963/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 1964/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 1965/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 1966/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 1967/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 1968/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 1969/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 1970/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 1971/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 1972/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 1973/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 1974/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 1975/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 1976/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 1977/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 1978/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 1979/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 1980/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 1981/2000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 1982/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 1983/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 1984/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 1985/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 1986/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 1987/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 1988/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 1989/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 1990/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 1991/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 1992/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 1993/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 1994/2000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 1995/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 1996/2000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 1997/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 1998/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 1999/2000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 2000/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0340 - accuracy: 1.0000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
# 훈련 과정 시각화 (손실)
ax1.plot(history.history['loss'])
ax1.set_title('Model loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend(['Train', 'Test'], loc='upper left')

# 훈련 과정 시각화 (정확도)
ax2.plot(history.history['accuracy'])
ax2.set_title('Model accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %% [markdown]
# ### 모델 성능을 검증 데이터로 평가

# %%
print('Final Output : ', model.predict(train__X))
## 4가지 데이터에 대한 예측 확률
# Out:
# 1/1 [==============================] - 0s 131ms/step
# Final Output :  [[0.03703112]
#  [0.9440482 ]
#  [0.9905916 ]
#  [0.03071233]]

# %%
# 테스트 데이터 정의
x_test = [[0, 0], [0, 1], [1, 0], [1, 1]]
y_test = [[0],[1],[1],[0]]

# 모델에 테스트 데이터를 입력
loss, accuracy = model.evaluate(x_test, y_test)

print('Test loss:', loss)

# 기존에 배운 sklearn의 성능 지표 출력으로 모델을 검증한다
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict(x_test, batch_size=1)
y_pred_bool = np.round(y_pred)

print("* 검증 데이터의 예측 결과")
print(y_pred_bool)


print("* Metrics") # accuracy를 관찰해보자.
print(classification_report(y_test, y_pred_bool, zero_division=0))

print("* Confusion matrix") # 혼동 행렬 confusion matrix를 관찰해보자.
cf = confusion_matrix(y_test, y_pred_bool)
ConfusionMatrixDisplay(cf).plot()
# Out:
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0340 - accuracy: 1.0000
# Test loss: 0.03398974984884262
# 4/4 [==============================] - 0s 3ms/step
# * 검증 데이터의 예측 결과
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# * Metrics
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# * Confusion matrix
